# %% [markdown]
# # Look at how the mocap data clusters based on various points-of-performance.

# %%
import pandas as pd
import numpy as np
import scipy.signal as scisig
from scipy.stats import norm

# module_path = os.path.abspath(os.path.join('../utils'))
# if module_path not in sys.path:
#     sys.path.append(module_path)
    
import ipynb.fs.full.Data_utils as data_utils
import ipynb.fs.full.Plotting_utils as plot_utils

# %%
data_path = "./../data/Train"
data_df = data_utils.load_participant_data_from_path(data_path, debug=False)
# Out:
# Reading in data from:  ./../data/Train/valerio_good0142.tsv
# Reading in data from:  ./../data/Train/valerio_bad0144.tsv
# Reading in data from:  ./../data/Train/jacob_bad0140.tsv
# Reading in data from:  ./../data/Train/jacob_good0092.tsv

# %%
data_df
# Out:
#                                                       barbell_right_x  \
# participant type point-perf. time
# valerio     good combined    2018-12-13 17:52:39.000          151.681
#                              2018-12-13 17:52:39.010          153.020
#                              2018-12-13 17:52:39.020          154.333
#                              2018-12-13 17:52:39.030          155.397
#                              2018-12-13 17:52:39.040          156.277
#                              2018-12-13 17:52:39.050          157.046
#                              2018-12-13 17:52:39.060          157.557
#                              2018-12-13 17:52:39.070          157.972
#                              2018-12-13 17:52:39.080          158.149
#                              2018-12-13 17:52:39.090          158.164
#                              2018-12-13 17:52:39.100          158.110
#                              2018-12-13 17:52:39.110          157.901
# ...

# %%
### TODO:
### - Basic k-means clustering on good and bad euclidian spine distances
### - Multivariate guassian clustering
### - Train basic anamoly detector if clustering looks good. (create notebook)
### - Train deep version of anamoly detector to classify good and bad on other test subjects. (create notebook)
